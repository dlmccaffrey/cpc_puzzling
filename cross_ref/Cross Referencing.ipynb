# %% [markdown]
# # Cross Referencing tables

# %% [markdown]
# Puzzles often incorporate things like airport codes to encode other values. This is a collection of such information that has been imported into DataFrames with pandas. This allows for easy table joining to decode the puzzles.

# %% [markdown]
# ## Files

# %%
# !ls
# Out:
# ASCII_extended.txt      caesar_cipher.csv       swift_current.csv
# Cross Referencing.ipynb companylistAMEX.csv     swift_current.xlsx
# SSN_areacode_clean.csv  companylistNASDAQ.csv   timezone.csv
# SSN_areacode_final.csv  companylistNYSE.csv     timezones2_old.txt
# airlines.txt            country_codes.csv       timezones_old.txt
# airports.txt            country_codes_old.txt   us_postal_codes.csv
# areacodes.txt           morse_code.csv          zone.csv
# areacodes_original.txt  ssn_areacode.txt

# %% [markdown]
# ## Imported Tables

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Extended ASCII
# <a href="http://www.ascii-code.com/">Source</a>.
# The html source code for the tables was copied using the Chrome Inspect tool and pasted into a text file. The table includes the decimal, octal, hexidecimal, binary, and html number for all characters in the extended ASCII table.

# %%
ASCII_extended_table = pd.read_html('ASCII_extended.txt', header=0)
# There were 4 table tags, which leads to a list of four DataFrames imported.
# The DataFrames need to be concatenated into one Data Frame.
ASCII_extended_table = pd.concat([x for x in ASCII_extended_table], ignore_index=True)
ASCII_extended_table[65:91] # Display all uppercase letters.
# Out:
#     DEC  OCT HEX      BIN Symbol HTML Number HTML Name  Description
# 65   65  101  41  1000001      A       &#65;       NaN  Uppercase A
# 66   66  102  42  1000010      B       &#66;       NaN  Uppercase B
# 67   67  103  43  1000011      C       &#67;       NaN  Uppercase C
# 68   68  104  44  1000100      D       &#68;       NaN  Uppercase D
# 69   69  105  45  1000101      E       &#69;       NaN  Uppercase E
# 70   70  106  46  1000110      F       &#70;       NaN  Uppercase F
# 71   71  107  47  1000111      G       &#71;       NaN  Uppercase G
# 72   72  110  48  1001000      H       &#72;       NaN  Uppercase H
# 73   73  111  49  1001001      I       &#73;       NaN  Uppercase I
# 74   74  112  4A  1001010      J       &#74;       NaN  Uppercase J
# 75   75  113  4B  1001011      K       &#75;       NaN  Uppercase K
# 76   76  114  4C  1001100      L       &#76;       NaN  Uppercase L
# 77   77  115  4D  1001101      M       &#77;       NaN  Uppercase M
# 78   78  116  4E  1001110      N       &#78;       NaN  Uppercase N
# 79   79  117  4F  1001111      O       &#79;       NaN  Uppercase O
# 80   80  120  50  1010000      P       &#80;       NaN  Uppercase P
# 81   81  121  51  1010001      Q       &#81;       NaN  Uppercase Q
# 82   82  122  52  1010010      R       &#82;       NaN  Uppercase R
# 83   83  123  53  1010011      S       &#83;       NaN  Uppercase S
# 84   84  124  54  1010100      T       &#84;       NaN  Uppercase T
# 85   85  125  55  1010101      U       &#85;       NaN  Uppercase U
# 86   86  126  56  1010110      V       &#86;       NaN  Uppercase V
# 87   87  127  57  1010111      W       &#87;       NaN  Uppercase W
# 88   88  130  58  1011000      X       &#88;       NaN  Uppercase X
# 89   89  131  59  1011001      Y       &#89;       NaN  Uppercase Y
# 90   90  132  5A  1011010      Z       &#90;       NaN  Uppercase Z

# %% [markdown]
# ### Airline Abbreviations
# <a href="https://cran.r-project.org/web/packages/nycflights13/nycflights13.pdf">Data documentation</a>.

# %%
airlines_abbr = pd.read_csv('airlines.txt', sep='\t')
airlines_abbr.head()
# Out:
#   carrier                    name
# 0      9E       Endeavor Air Inc.
# 1      AA  American Airlines Inc.
# 2      AS    Alaska Airlines Inc.
# 3      B6         JetBlue Airways
# 4      DL    Delta Air Lines Inc.

# %% [markdown]
# ### Airport Abbreviations
# <a href="https://cran.r-project.org/web/packages/nycflights13/nycflights13.pdf">Data documentation</a>.

# %%
airport_abbr = pd.read_csv('airports.txt', sep='\t')
airport_abbr.head()
# Out:
#    faa                           name        lat        lon   alt  tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044  -5   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264  -6   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801  -6   A
# 3  06N                Randall Airport  41.431912 -74.391561   523  -5   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11  -5   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %% [markdown]
# ### Timezone information
# <a href="https://timezonedb.com/download">Data documentation</a>. The information comes as three separate tables and has to be joined into one table.

# %%
country_codes_table = pd.read_csv('country_codes.csv', header=None, names=['country_code', 'country_name'])
timezones = pd.read_csv('timezone.csv', header=None, names=["zone_id","abbreviation","time_start","gmt_offset","dst"])
zones = pd.read_csv('zone.csv', header=None, names=["zone_id","country_code","zone_name"])
timezones_all_table = zones.merge(timezones, on='zone_id', how='outer')
timezones_all_table = timezones_all_table.merge(country_codes_table, on='country_code', how='outer')
timezones_all_table.head()
# Out:
#    zone_id country_code       zone_name abbreviation    time_start  \
# 0      1.0           AD  Europe/Andorra          LMT -2.177453e+09
# 1      1.0           AD  Europe/Andorra          WET -2.177453e+09
# 2      1.0           AD  Europe/Andorra          CET -7.338816e+08
# 3      1.0           AD  Europe/Andorra         CEST  4.810788e+08
# 4      1.0           AD  Europe/Andorra          CET  4.968036e+08
#
#    gmt_offset  dst country_name
# 0       364.0  0.0      Andorra
# 1         0.0  0.0      Andorra
# 2      3600.0  0.0      Andorra
# 3      7200.0  1.0      Andorra
# 4      3600.0  0.0      Andorra

# %% [markdown]
# ### Telephone area codes
# <a href="https://www.allareacodes.com/area_code_listings_by_state.htm">Source</a>. The data was copied from the table on the right using the Chrome Inspect tool. This was pasted into a file called ```areacodes.txt```.

# %% [markdown]
# The original source code was created using div tags:

# %%
# !cat areacodes_original.txt
# Out:
# <div id="codes_2" class="codes_container" style="display: block;"><a href="/201"><b>201</b> - Newark, NJ</a><br><a href="/202"><b>202</b> - Washington, DC</a><br><a href="/203"><b>203</b> - New Haven, CT</a><br><a href="/204"><b>204</b> - Yorkton, MB</a><br><a href="/205"><b>205</b> - Birmingham, AL</a><br><a href="/206"><b>206</b> - Seattle, WA</a><br><a href="/207"><b>207</b> - Portland, ME</a><br><a href="/208"><b>208</b> - Boise, ID</a><br><a href="/209"><b>209</b> - Fresno, CA</a><br><a href="/210"><b>210</b> - San Antonio, TX</a><br><a href="/212"><b>212</
> <td> Montgomery, AL</td></tr><tr><td>336</td> <td> Greensboro, NC</td></tr><tr><td>337</td> <td> Lafayette, LA</td></tr><tr><td>339</td> <td> Boston, MA</td></tr><tr><td>340</td> <td> Charlotte Amalie, VI</td></tr><tr><td>343</td> <td> Vankleek Hill, ON</td></tr><tr><td>346</td> <td> Houston, TX</td></tr><tr><td>347</td> <td> Brooklyn, NY</td></tr><tr><td>351</td> <td> Danvers, MA</td></tr><tr><td>352</td> <td> Gainesville, FL</td></tr><tr><td>360</td> <td> Seattle, WA</td></tr><tr><td>361</td> <td> Corpus Christi, TX</td></tr><tr><td>365</td> <td> Tottenham, ON</td></tr><tr><td>385</td> <td> Salt Lake City, UT</td></tr><tr><td>386</td> <td> Daytona Beach, FL</td></tr><tr><td>401</td> <td> Providence, RI</td></tr><tr><td>402</td> <td> Omaha, NE</td></tr><tr><td>403</td> <td> Youngstown, AB</td></tr><tr><td>404</td> <td> Atlanta, GA</td></tr><tr><td ...

# %%
areacodes_table = pd.read_html('areacodes.txt', header=0)
areacodes_table = areacodes_table[0]
areacodes_table.head()
# Out:
#    Area Code            City
# 0        201      Newark, NJ
# 1        202  Washington, DC
# 2        203   New Haven, CT
# 3        204     Yorkton, MB
# 4        205  Birmingham, AL

# %% [markdown]
# ### Stock ticker symbols
# <a href="http://www.nasdaq.com/screening/company-list.aspx">Source</a>.

# %%
AMEX_table = pd.read_csv('companylistAMEX.csv', header=0, index_col=False)
AMEX_table.head()
# Out:
#            Symbol                                               Name LastSale  \
# 0            XXII                            22nd Century Group, Inc     0.93
# 1             FAX              Aberdeen Asia-Pacific Income Fund Inc     4.91
# 2             IAF                 Aberdeen Australia Equity Fund Inc     5.98
# 3              CH                          Aberdeen Chile Fund, Inc.     6.63
# 4  ABE             Aberdeen Emerging Markets Smaller Company Oppo...    12.52
#
#       MarketCap ADR TSO IPOyear                 Sector               Industry  \
# 0  8.434925e+07     n/a     n/a  Consumer Non-Durables  Farming/Seeds/Milling
# 1  1.243539e+09     n/a     n/a                    n/a                    n/a
# 2  1.359991e+08     n/a     n/a                    n/a                    n/a
# 3  6.223248e+07     n/a     n/a                    n/a                    n/a
# 4  1.207421e+08     n/a     n/a                    n/a                    n/a
#
#                        Summary Quote
# 0  http://www.nasdaq.com/symbol/xxii
# 1   http://www.nasdaq.com/symbol/fax
# 2   http://www.nasdaq.com/symbol/iaf
# 3    http://www.nasdaq.com/symbol/ch
# 4   http://www.nasdaq.com/symbol/abe

# %%
NASDAQ_table = pd.read_csv('companylistNASDAQ.csv', header=0, index_col=False)
NASDAQ_table.head()
# Out:
#   Symbol                                    Name LastSale     MarketCap  \
# 0    PIH  1347 Property Insurance Holdings, Inc.     7.75  4.618121e+07
# 1   FLWS                 1-800 FLOWERS.COM, Inc.    10.25  6.720828e+08
# 2   FCCY           1st Constitution Bancorp (NJ)       19  1.518820e+08
# 3   SRCE                  1st Source Corporation       47  1.217656e+09
# 4   VNET                    21Vianet Group, Inc.     5.83  3.366823e+08
#
#     ADR TSO IPOyear             Sector  \
# 0       n/a     n/a            Finance
# 1       n/a     n/a  Consumer Services
# 2       n/a     n/a            Finance
# 3       n/a     n/a            Finance
# 4  57749958     n/a         Technology
#
#                                           Industry  \
# 0                       Property-Casualty Insurers
# 1                           Other Specialty Stores
# 2                             Savings Institutions
# 3                                      Major Banks
# 4  Computer Software: Programming, Data Processing
#
#                        Summary Quote
# 0   http://www.nasdaq.com/symbol/pih
# 1  http://www.nasdaq.com/symbol/flws
# 2  http://www.nasdaq.com/symbol/fccy
# 3  http://www.nasdaq.com/symbol/srce
# 4  http://www.nasdaq.com/symbol/vnet

# %%
NYSE_table = pd.read_csv('companylistNYSE.csv', header=0, index_col=False)
NYSE_table.head()
# Out:
#   Symbol                    Name LastSale     MarketCap ADR TSO IPOyear  \
# 0    DDD  3D Systems Corporation    14.64  1.656711e+09     n/a     n/a
# 1    MMM              3M Company   192.36  1.146850e+11     n/a     n/a
# 2   WBAI         500.com Limited    12.94  5.369849e+08     n/a     n/a
# 3   WUBA             58.com Inc.    37.09  5.367047e+09     n/a     n/a
# 4    AHC   A.H. Belo Corporation      6.3  1.365604e+08     n/a     n/a
#
#               Sector                                         Industry  \
# 0         Technology          Computer Software: Prepackaged Software
# 1        Health Care                       Medical/Dental Instruments
# 2  Consumer Services            Services-Misc. Amusement & Recreation
# 3         Technology  Computer Software: Programming, Data Processing
# 4  Consumer Services                             Newspapers/Magazines
#
#                        Summary Quote
# 0   http://www.nasdaq.com/symbol/ddd
# 1   http://www.nasdaq.com/symbol/mmm
# 2  http://www.nasdaq.com/symbol/wbai
# 3  http://www.nasdaq.com/symbol/wuba
# 4   http://www.nasdaq.com/symbol/ahc

# %% [markdown]
# ### SSN Area numbers
# <a href="http://www.nasdaq.com/screening/company-list.aspx">Source</a>. The source code for the table was copied using the Chrome Inspect tool and pasted into a text file called ```ssn_areacode.txt```. The orignal table was unpivoted and saved to ```ssn_areacode_final.csv```. Leading zeros were removed by default.

# %%
SSN_table = pd.read_csv('ssn_areacode_final.csv', header=0, index_col=False)
SSN_table.head()
# Out:
#    SSN Areacode       Location
# 0             0  New Hampshire
# 1             1  New Hampshire
# 2             2  New Hampshire
# 3             3  New Hampshire
# 4             4          Maine

# %% [markdown]
# ### ZIP codes
# <a href="https://www.aggdata.com/node/86">Source</a>. Leading zeros were removed by default.

# %%
zipcode_table = pd.read_csv('us_postal_codes.csv', index_col=False)
zipcode_table
# Out:
#        Postal Code       Place Name          State State Abbreviation  \
# 0              210       Portsmouth  New Hampshire                 NH
# 1              211       Portsmouth  New Hampshire                 NH
# 2              212       Portsmouth  New Hampshire                 NH
# 3              213       Portsmouth  New Hampshire                 NH
# 4              214       Portsmouth  New Hampshire                 NH
# 5              215       Portsmouth  New Hampshire                 NH
# 6              401    Pleasantville       New York                 NY
# 7              501       Holtsville       New York                 NY
# 8              544       Holtsville       New York                 NY
# 9             1001           Agawam  Massachusetts                 MA
# 10            1002          Amherst  Massachusetts                 MA
# 11            1003          Amherst  Massachusetts                 MA
# 12            1004          Amherst  Massachusetts                 MA
# 13            1005            Barre  Massachusetts                 MA
# 14            1007      Belchertown  Massachusetts                 MA
# 23                    Hampden   42.1707   -72.6048
# 24                    Hampden   42.1934   -72.5544
# 25                  Hampshire   42.4633   -72.9202
# 26                  Hampshire   42.3683   -72.7688
# 27                    Hampden   42.0672   -72.5056
# 28                  Berkshire   42.1909   -73.0517
# 29                    Hampden   42.0718   -72.6751
# ...                       ...       ...        ...
# 43552  Juneau City and Boroug   58.3835  -134.1978
# 43553                     NaN   58.3271  -134.4742
# 43554   Skagway-Hoonah-Angoon   57.5005  -134.5860
# 43555  Juneau City and Boroug   58.4494  -134.7003
# 43556  Juneau City and Boroug   58.2756  -134.3950
# 43557   Skagway-Hoonah-Angoon   58.3318  -135.1813
# 43558   Skagway-Hoonah-Angoon   58.4284  -135.7615
# 43559                  Haines   59.2519  -135.5420
# 43560   Skagway-Hoonah-Angoon   58.0977  -135.4316
# 43561  Wrangell-Petersburg (C   56.9736  -133.9360
# 43562   Skagway-Hoonah-Angoon   58.3318  -135.1813
# 43563  Wrangell-Petersburg (C   56.8271  -133.1607
# 43564  Sitka City and Borough   57.0514  -135.3166
# 43565  Wrangell-Petersburg (C   56.5360  -132.8279
# 43566   Skagway-Hoonah-Angoon   59.4685  -135.3018
# 43567   Skagway-Hoonah-Angoon   57.7943  -135.1844
# 43568  Juneau City and Boroug   58.3835  -134.1978
# 43569       Ketchikan Gateway   55.3720  -131.6832
# 43570   Prince of Wales-Outer   55.5179  -132.0032
# 43571   Prince of Wales-Outer   55.9524  -132.7503
# 43572   Prince of Wales-Outer   55.6609  -132.5138
# 43573   Prince of Wales-Outer   55.4732  -133.1171
# 43574   Prince of Wales-Outer   55.2087  -132.8259
# 43575   Prince of Wales-Outer   55.5179  -132.0032
# 43576   Prince of Wales-Outer   55.5526  -133.0555
# 43577   Prince of Wales-Outer   55.1215  -131.5790
# 43578   Prince of Wales-Outer   55.5179  -132.0032
# 43579       Ketchikan Gateway   55.3954  -131.6754
# 43580  Wrangell-Petersburg (C   56.4335  -132.3529
# 43581       Ketchikan Gateway   55.5420  -131.4327
#
# [43582 rows x 7 columns]

# %% [markdown]
# ### Other letter codes
# <a href="https://en.wikipedia.org/wiki/Morse_code">Morse code</a>. "s" means short, "l" means long. <a href="https://en.wikipedia.org/wiki/NATO_phonetic_alphabet">NATO Phonetic Alphabet</a>. <a href="https://en.wikipedia.org/wiki/Tap_code">Tap code</a>. The code is represented as a two digit number with the first digit being the row and the second digit being the column.

# %%
morse_code_NATO_tap = pd.read_csv('morse_code.csv', index_col=False)
morse_code_NATO_tap.head()
# Out:
#   Letter Morse Code     NATO   Tap
# 0      A         sl     alfa  11.0
# 1      B       lsss    bravo  12.0
# 2      C       lsls  charlie  13.0
# 3      D        lss    delta  14.0
# 4      E          s     echo  15.0

# %% [markdown]
# ### Letter index for Caesar ciphers

# %%
alphabet_numbers = pd.read_csv('caesar_cipher.csv', index_col=False)
alphabet_numbers.head()
# Out:
#   Letter  Number
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       4
# 4      e       5

# %% [markdown]
# # Tables
# * ASCII_table
# * airlines_abbr
# * airport_abbr
# * timezones_all_table
# * areacodes_table
# * AMEX_table
# * NASDAQ_table
# * NYSE_table
# * SSN areacodes
# * zipcodes
# * morse_code_NATO_tap
# * alphabet_numbers

# %% [markdown]
# ## Yellow Noise

# %% [markdown]
# <a href="https://www.collegepuzzlechallenge.com/Puzzles/ViewPuzzle.ashx?id=1357">Source puzzle</a>. Closed mouth corresponds to a 1, open mouth corresponds to a 0.

# %%
#enter binaries as a list of numbers without zeros at beginning
puzzle = [10011,
          10000,
           1100,
              1,
          10100]

# %% [markdown]
# The extended ASCII table I have adds an additional 1000000 to the binary values for letters. I need to account for this.

# %%
puzzle = [x + 1000000 for x in puzzle] 
puzzle_df = pd.DataFrame(puzzle, columns=['BIN'])
puzzle_df
# Out:
#        BIN
# 0  1010011
# 1  1010000
# 2  1001100
# 3  1000001
# 4  1010100

# %%
answer = puzzle_df.merge(ASCII_extended_table, how='left') #a left join preserves the order
answer
# Out:
#        BIN  DEC  OCT HEX Symbol HTML Number HTML Name  Description
# 0  1010011   83  123  53      S       &#83;       NaN  Uppercase S
# 1  1010000   80  120  50      P       &#80;       NaN  Uppercase P
# 2  1001100   76  114  4C      L       &#76;       NaN  Uppercase L
# 3  1000001   65  101  41      A       &#65;       NaN  Uppercase A
# 4  1010100   84  124  54      T       &#84;       NaN  Uppercase T

# %% [markdown]
# The answer is SPLAT.

# %% [markdown]
# # Swift Current

# %% [markdown]
# <a href="https://www.collegepuzzlechallenge.com/Puzzles/2017/SwiftCurrent/">Source puzzle</a>. Each clip ended with sound bites of a rimshot and/or a cymbol crash. These sounds correspond to Morse code, with the rimshots being short and the cymbol crashes being long. The clips then had to be reordered according to the song <a href="https://www.youtube.com/watch?v=nfWlot6h_JM">Shake it Off</a> by Taylor Swift. The final ordering was saved to ```swift_current.csv```.

# %%
swift_current = pd.read_csv('swift_current.csv', index_col=None)
swift_current.head()
# Out:
#   Morse Code
# 0         ls
# 1          s
# 2       lssl
# 3          l
# 4        sll

# %%
answer = swift_current.merge(morse_code_NATO_tap, how='left', on='Morse Code')
answer
# Out:
#    Morse Code Letter      NATO   Tap
# 0          ls      N  november  33.0
# 1           s      E      echo  15.0
# 2        lssl      X      xray  53.0
# 3           l      T     tango  44.0
# 4         sll      W   whiskey  52.0
# 5         lll      O     oscar  34.0
# 6         sls      R     romeo  42.0
# 7         lss      D     delta  14.0
# 8          sl      A      alfa  11.0
# 9        ssls      F   foxtrot  21.0
# 10          l      T     tango  44.0
# 11          s      E      echo  15.0
# 12        sls      R     romeo  42.0
# 13         ss      I     india  24.0
# 14        lsl      K      kilo  13.0
# 15         ls      N  november  33.0
# 16          s      E      echo  15.0
# 17        sll      W   whiskey  52.0
# 18       lsll      Y    yankee  54.0
# 19        lll      O     oscar  34.0
# 20        ssl      U   uniform  45.0
# 21        sll      W   whiskey  52.0
# 22          s      E      echo  15.0
# 23        sls      R     romeo  42.0
# 24          s      E      echo  15.0

# %%
answer_list = answer.Letter.tolist()
answer_string = ''.join(answer_list)
answer_string
# Out:
# 'NEXTWORDAFTERIKNEWYOUWERE'

# %% [markdown]
# The new clue is "Next word after I knew you were." The answer is TROUBLE, from <a href="https://www.youtube.com/watch?v=vNoKguSdy4Y">I Knew You Were Trouble</a>, another Taylor Swift song.

# %% [markdown]
# # Gone Fish
# <a href="https://www.collegepuzzlechallenge.com/Puzzles/ViewPuzzle.ashx?id=1366">Puzzle</a>. I wanted to see if the letters on the fish corresponded to any abbreviations.

# %%
fishes = ['BAN', 'VAN', 'AKE', 'RAV', 'TOM', 'DAN', 'FIN', 'GLO', 'PUN', 'PER', 'SSY']
fishes_df = pd.DataFrame(fishes, columns=['fishes'])
fishes_df
# Out:
#    fishes
# 0     BAN
# 1     VAN
# 2     AKE
# 3     RAV
# 4     TOM
# 5     DAN
# 6     FIN
# 7     GLO
# 8     PUN
# 9     PER
# 10    SSY

# %%
answer = fishes_df.merge(airport_abbr, left_on='fishes', right_on='faa')
answer
# Out:
# Empty DataFrame
# Columns: [fishes, faa, name, lat, lon, alt, tz, dst, tzone]
# Index: []

# %%
answer = fishes_df.merge(AMEX_table, left_on='fishes', right_on='Symbol')
answer
# Out:
#   fishes Symbol                              Name LastSale     MarketCap  \
# 0    GLO    GLO  Clough Global Opportunities Fund    10.08  5.198665e+08
# 1    SSY    SSY      SunLink Health Systems, Inc.     1.54  1.454285e+07
#
#   ADR TSO IPOyear       Sector                     Industry  \
# 0     n/a     n/a          n/a                          n/a
# 1     n/a     n/a  Health Care  Hospital/Nursing Management
#
#                       Summary Quote
# 0  http://www.nasdaq.com/symbol/glo
# 1  http://www.nasdaq.com/symbol/ssy

# %%
answer = fishes_df.merge(NASDAQ_table, left_on='fishes', right_on='Symbol')
answer
# Out:
# Empty DataFrame
# Columns: [fishes, Symbol, Name, LastSale, MarketCap, ADR TSO, IPOyear, Sector, Industry, Summary Quote]
# Index: []

# %%
answer = fishes_df.merge(NYSE_table, left_on='fishes', right_on='Symbol')
answer
# Out:
#   fishes Symbol                     Name LastSale     MarketCap ADR TSO  \
# 0    DAN    DAN        Dana Incorporated    19.53  2.812639e+09     n/a
# 1    PER    PER  SandRidge Permian Trust     3.05  1.601250e+08     n/a
#
#   IPOyear         Sector              Industry  \
# 0     n/a  Capital Goods     Auto Parts:O.E.M.
# 1     n/a         Energy  Oil & Gas Production
#
#                       Summary Quote
# 0  http://www.nasdaq.com/symbol/dan
# 1  http://www.nasdaq.com/symbol/per

# %% [markdown]
# The puzzle is not referencing airports or stock symbols.

# %% [markdown]
# # Port Codes
# <a href="https://www.collegepuzzlechallenge.com/Puzzles/ViewPuzzle.ashx?id=1381">Puzzle</a>. The "IP addresses" for each source and destination are words encoded by the numbers 1-26. Merging the "IP address" numbers with the ```alphabet_numbers``` DataFrame gives the corresponding words that are used to find a map location on <a href="https://map.what3words.com/kicks.pasta.steer">what3words</a>.

# %%
word = [18,5,7,1,18,4]
word_df = pd.DataFrame(word, columns=['Number'])
word_df
# Out:
#    Number
# 0      18
# 1       5
# 2       7
# 3       1
# 4      18
# 5       4

# %%
answer = word_df.merge(alphabet_numbers, how='left')
answer
# Out:
#    Number Letter
# 0      18      r
# 1       5      e
# 2       7      g
# 3       1      a
# 4      18      r
# 5       4      d
